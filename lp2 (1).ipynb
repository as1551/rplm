# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv('temperatures.csv')

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0    29.97  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1    29.12  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2    29.04  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3    29.20  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4    30.67  27.52  23.82   28.30    22.25    30.00    31.33    26.57
# ..     ...    ...    ...     ...      ...      ...      ...      ...
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69
#
# [117 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
x = df["YEAR"]
y = df["ANNUAL"]

# %%
x=x.values
x=x.reshape(117,1)
x
# Out:
# array([[1901],
#        [1902],
#        [1903],
#        [1904],
#        [1905],
#        [1906],
#        [1907],
#        [1908],
#        [1909],
#        [1910],
#        [1911],
#        [1912],
#        [1913],
#        [1914],
#        [1915],
#        [1916],
#        [1917],
#        [1918],
#        [1919],
#        [1920],
#        [1921],
#        [1922],
#        [1923],
#        [1924],
#        [1925],
#        [1926],
#        [1927],
#        [1928],
#        [1929],
#        [1930],
#        [1931],
#        [1932],
#        [1933],
#        [1934],
#        [1935],
#        [1936],
#        [1937],
#        [1938],
#        [1939],
#        [1940],
#        [1941],
#        [1942],
#        [1943],
#        [1944],
#        [1945],
#        [1946],
#        [1947],
#        [1948],
#        [1949],
#        [1950],
#        [1951],
#        [1952],
#        [1953],
#        [1954],
#        [1955],
#        [1956],
#        [1957],
#        [1958],
#        [1959],
#        [1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017]])

# %%
y
# Out:
# 0      28.96
# 1      29.22
# 2      28.47
# 3      28.49
# 4      28.30
#        ...
# 112    29.81
# 113    29.72
# 114    29.90
# 115    31.63
# 116    31.42
# Name: ANNUAL, Length: 117, dtype: float64

# %%
plt.xlabel('year')
plt.ylabel('tempreture')
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
print('xtrain:',x_train.shape)
# Out:
# xtrain: (87, 1)

# %%
print('xtest:',x_test.shape)
# Out:
# xtest: (30, 1)

# %%
print('ytrain:',y_train.shape)
# Out:
# ytrain: (87,)

# %%
print('ytest:',y_test.shape)
# Out:
# ytest: (30,)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([29.88069822, 29.11554803, 28.75935743, 29.15512477, 29.68281455,
#        28.9572411 , 29.18150926, 29.81473699, 28.65381948, 28.41635907,
#        29.84112148, 29.04958681, 29.65643006, 28.82531865, 28.8385109 ,
#        29.30023946, 29.7883525 , 29.70919904, 28.58785825, 28.66701172,
#        29.3134317 , 29.20789375, 28.77254968, 29.52450761, 28.81212641,
#        29.53769986, 28.79893417, 29.74877577, 28.98362559, 29.36620068])

# %%
error=y_pred-y_test

# %%
error
# Out:
# 111    0.070698
# 53     0.195548
# 26     0.169357
# 56     0.515125
# 96     0.632815
# 41    -0.022759
# 58     0.161509
# 106   -0.025263
# 18    -0.006181
# 0     -0.543641
# 108   -0.458879
# 48     0.159587
# 94    -0.523570
# 31    -0.264681
# 32     0.348511
# 67     0.230239
# 104    0.188353
# 98    -0.100801
# 13    -0.072142
# 19    -0.092988
# 68    -0.296568
# 60     0.487894
# 27    -0.207450
# 84    -0.085492
# 30    -0.337874
# 85     0.207700
# 29     0.148934
# 101   -0.481224
# 43     0.093626
# 72    -0.073799
# Name: ANNUAL, dtype: float64

# %%
plt.title('temperature vs year')
plt.xlabel('year')
plt.ylabel('tempreture')
plt.scatter(x,y)
plt.plot(x_test,y_pred)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error,r2_score, accuracy_score

# %%
print('MAE',mean_absolute_error(y_test,y_pred))
print("************")
print('MSE',mean_squared_error(y_test,y_pred))
print("************")
print('R2SCORE',r2_score(y_test,y_pred))
print("************")
# Out:
# MAE 0.2401069193991282
# ************
# MSE 0.08921118985545887
# ************
# R2SCORE 0.6640527988954088
# ************

# %%
print(model.predict([[2030]])[0])
# Out:
# 30.118158617096423
